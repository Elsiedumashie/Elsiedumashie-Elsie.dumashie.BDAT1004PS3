# %% [markdown]
# ##Quesion 1
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
# Occupations
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called users
# Step 4. Discover what is the mean age per occupation
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
# Step 6. For each occupation, calculate the minimum and maximum ages
# Step 7. For each combination of occupation and sex, calculate the mean age
# Step 8. For each occupation present the percentage of women and men

# %%
#Task 2
#import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

# 1.2 Data Loading
## Task 2 - Load/ data set  dataset
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
user_df = pd.read_csv(url, delimiter = "|")

# %%
#1.3Assign it to a variable called users
users=user_df
users.head(10)
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344
# 7        8   36      M  administrator    05201
# 8        9   29      M        student    01002
# 9       10   53      M         lawyer    90703

# %%
#1.4 Discover what is the mean age per occupation
#mean1 = (mean(users['age']))
#print("Mean age per occupation  is :", mean1)
users.groupby("occupation").age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
#1.5 Discover the Male ratio per occupation and sort it from the most to the least
users['male_ratio'] = np.where(users.gender == 'M', 1, 0)

(users.groupby('occupation').male_ratio.sum()/users.groupby('occupation').gender.count()).round(2).sort_values(ascending = False)
# Out:
# occupation
# doctor           1.00
# engineer         0.97
# technician       0.96
# retired          0.93
# executive        0.91
# programmer       0.91
# scientist        0.90
# entertainment    0.89
# lawyer           0.83
# salesman         0.75
# educator         0.73
# student          0.69
# other            0.66
# marketing        0.62
# writer           0.58
# none             0.56
# administrator    0.54
# artist           0.54
# librarian        0.43
# healthcare       0.31
# homemaker        0.14
# dtype: float64

# %%
#1.6. For each occupation, calculate the minimum and maximum ages
users.groupby("occupation").age.agg([min, max])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
#1.7. For each combination of occupation and sex, calculate the mean age

users.groupby(["occupation","gender"]).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
#1.8 For each occupation present the percentage of women and men
#df to apply count to the gender
gender_count = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})
occup_count = users.groupby(['occupation']).agg('count')
occup_gender = gender_count.div(occup_count, level = "occupation")
occup_gender.loc[: , 'gender']
# Out:
# occupation     gender
# administrator  F         0.455696
#                M         0.544304
# artist         F         0.464286
#                M         0.535714
# doctor         M         1.000000
# educator       F         0.273684
#                M         0.726316
# engineer       F         0.029851
#                M         0.970149
# entertainment  F         0.111111
#                M         0.888889
# executive      F         0.093750
#                M         0.906250
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         F         0.166667
#                M         0.833333
# librarian      F         0.568627
#                M         0.431373
# marketing      F         0.384615
#                M         0.615385
# none           F         0.444444
#                M         0.555556
# other          F         0.342857
#                M         0.657143
# ...

# %% [markdown]
# ##Question 2
# .Euro Teams
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12
# Step 4. Select only the Goal column
# Step 5. How many team participated in the Euro2012?
# Step 6. What is the number of columns in the dataset?
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
# Step 9. Calculate the mean Yellow Cards given per Team.Step 10. Filter teams that scored more than 6 goalsStep 11. Select the teams that start with G
# Step 12. Select the first 7 columns
# Step 13. Select all columns except the last 3
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
#2.1 Import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

# %%
#2.2. Import the dataset from this address
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv'

# %%
#2.3Assign it to a variable called euro12
euro12= pd.read_csv(url, delimiter = ",")
euro12.head(10)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
# 8     Netherlands      2               12                36             25.0%
# 9          Poland      2               15                23             39.4%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# ...

# %%
#2.4. Select only the Goal column
euro12["Goals"]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#2.5How many team participated in the Euro2012?
euro12.Team.count()
# Out:
# 16

# %%
#2.6 What is the number of columns in the dataset?
print(euro12.shape[1])
# Out:
# 35

# %%
#2. 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
discipline =euro12[["Team","Yellow Cards","Red Cards"]]
print(discipline)
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#2.8. Sort the teams by Red Cards, then to Yellow Cards
discipline.sort_values(["Red Cards","Yellow Cards"],ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
#2.9. Calculate the mean Yellow Cards given per Team
discipline["Yellow Cards"].mean()
# Out:
# 7.4375

# %%
#2.10. Filter teams that scored more than 6 goals
euro12[euro12.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#2.11. Select the teams that start with G
euro12[euro12.Team.str[0] == 'G']
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#2.12. Select the first 7 columns
#to get the first  7 columns use iloc
euro12.iloc[:, : 7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#1.13. Select all columns except the last 3
euro12.iloc[:, : -3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#1.14. Present only the Shooting Accuracy from England, Italy and Russia


euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# ##Question 3
# Housing
# Step 1. Import the necessary libraries
# Step 2. Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000
# Step 3. Create a DataFrame by joinning the Series by column
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
# Step 6. Ops it seems it is going only until index 99. Is it true?
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
#3. 1. Import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

# %%
from re import S
#3.2. Create 3 differents Series, each of length 100, as follows: • The first a random number from 1 to 4 • The second a random number from 1 to 3 • The third a random number from 10,000 to 30,000
s1 = pd.Series(np.random.randint(1, 5, 100))
s2 = pd.Series(np.random.randint(1, 4, 100))
s3 = pd.Series(np.random.randint(10000, 30001, 100))

# %%
#.3.3 Create a DataFrame by joinning the Series by column
housing_df = pd.concat([s1, s2, s3], axis=1)
housing_df.head()
# Out:
#    0  1      2
# 0  1  3  27758
# 1  2  1  17819
# 2  3  1  12757
# 3  3  3  27751
# 4  1  2  28196

# %%
#3.4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
housing_df.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
housing_df.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      1       3            27758
# 1      2       1            17819
# 2      3       1            12757
# 3      3       3            27751
# 4      1       2            28196

# %%
#3.5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.concat([s1, s2, s3], ignore_index=True)
bigcolumn = bigcolumn.to_frame()
print(type(bigcolumn))
print(bigcolumn)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          0
# 0        1
# 1        2
# 2        3
# 3        3
# 4        1
# ..     ...
# 295  14475
# 296  10638
# 297  18008
# 298  26995
# 299  28297
#
# [300 rows x 1 columns]

# %%
#3.6. Ops it seems it is going only until index 99. Is it true?

len(bigcolumn)
print (bigcolumn.index.max())
print( bigcolumn.index.max() == 99)
# Out:
# 299
# False

# %%
#3.7. Reindex the DataFrame so it goes from 0 to 299
bigcolumn.reset_index(drop=True, inplace=True)
print(bigcolumn)
# Out:
#          0
# 0        1
# 1        2
# 2        3
# 3        3
# 4        1
# ..     ...
# 295  14475
# 296  10638
# 297  18008
# 298  26995
# 299  28297
#
# [300 rows x 1 columns]

# %% [markdown]
# ##Question 4
# Wind Statistics
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
# You should be able to perform all of these operations without using a for loop or other looping construct.
# The data in 'wind.data' has the following format:
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.711. Import the necessary libraries
# Step 2. Import the dataset from the attached file wind.txt
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
# Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.
# Step 7. Compute how many non-missing values there are in total.
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# A single number for the entire dataset.
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
# A different set of numbers for each location.
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
# A different set of numbers for each day.
# Step 11. Find the average windspeed in January for each location.
# Treat January 1961 and January 1962 both as January.
# Step 12. Downsample the record to a yearly frequency for each location.
# Step 13. Downsample the record to a monthly frequency for each location.
# Step 14. Downsample the record to a weekly frequency for each location.
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
#1. Import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean
import datetime as dt

# %%
#Step 2. Import the dataset from the attached file wind.txt
data = pd.read_fwf("wind.txt")

# %%
#Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
data['datetime'] = pd.to_datetime(data.Yr.astype(str)+data.Mo.astype(str)+data.Dy.astype(str), format='%y%m%d')
data.set_index(data['datetime'])
data = data.drop(['Yr', 'Mo', 'Dy'], axis=1)

# %%
#Step 4Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
def date_1900(datetime):
  if str(datetime.year).startswith("20"):
    return datetime - pd.DateOffset(years=100)
  return datetime

data['datetime'] = data['datetime'].map(date_1900)

# %%
#Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
data['datetime'] = data['datetime'].astype('datetime64[ns]')
data = data.set_index(pd.to_datetime(data['datetime']))

# %%
#Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.
data.isna().sum()
# Out:
# RPT         6
# VAL         3
# ROS         2
# KIL         5
# SHA         2
# BIR         0
# DUB         3
# CLA         2
# MUL         3
# CLO         1
# BEL         0
# MAL         4
# datetime    0
# dtype: int64

# %%
#Step 7. Compute how many non-missing values there are in total.
data.notna().sum()
# Out:
# RPT         6568
# VAL         6571
# ROS         6572
# KIL         6569
# SHA         6572
# BIR         6574
# DUB         6571
# CLA         6572
# MUL         6571
# CLO         6573
# BEL         6574
# MAL         6570
# datetime    6574
# dtype: int64

# %%
#Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
#A single number for the entire dataset.
data.mean().sum()
# Out:
# <ipython-input-11-8fabd1c06b5f>:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.mean().sum()
# 122.73578833004325

# %%
#Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days.A different set of numbers for each location.
def cal_min_max_mean_std(loc):
  return pd.Series(index=['min', 'max', 'mean', 'std'], data=[loc.min(), loc.max(), loc.mean(), loc.std()])

loc_stats = data[['RPT', 'VAL', 'ROS', 'KIL', 'SHA', 'BIR', 'DUB', 'CLA', 'MUL', 'CLO', 'BEL', 'MAL']].apply(cal_min_max_mean_std)
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# std    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# min    0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# mean   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# std    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %%
#Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#A different set of numbers for each day.
day_stats = data[['RPT', 'VAL', 'ROS', 'KIL', 'SHA', 'BIR', 'DUB', 'CLA', 'MUL', 'CLO', 'BEL', 'MAL']].apply(cal_min_max_mean_std, axis=1)
day_stats['datetime'] = data['datetime']
day_stats
# Out:
#              min    max       mean       std   datetime
# datetime
# 1961-01-01  9.29  18.50  13.018182  2.808875 1961-01-01
# 1961-01-02  6.50  17.54  11.336364  3.188994 1961-01-02
# 1961-01-03  6.17  18.50  11.641818  3.681912 1961-01-03
# 1961-01-04  1.79  11.75   6.619167  3.198126 1961-01-04
# 1961-01-05  6.17  13.33  10.630000  2.445356 1961-01-05
# ...          ...    ...        ...       ...        ...
# 1978-12-27  8.08  40.08  16.708333  7.868076 1978-12-27
# 1978-12-28  5.00  41.46  15.150000  9.687857 1978-12-28
# 1978-12-29  8.71  29.58  14.890000  5.756836 1978-12-29
# 1978-12-30  9.13  28.79  15.367500  5.540437 1978-12-30
# 1978-12-31  9.59  27.29  15.402500  5.702483 1978-12-31
#
# [6574 rows x 5 columns]

# %%
#Step 11. Find the average windspeed in January for each location.Treat January 1961 and January 1962 both as January.
data[data['datetime'].dt.month == 1].mean()
# Out:
# <ipython-input-14-509146787c50>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data[data['datetime'].dt.month == 1].mean()
# RPT    14.407735
# VAL    12.362146
# ROS    13.290470
# KIL     6.926239
# SHA    11.205064
# BIR     7.827393
# DUB    11.953120
# CLA     9.377511
# MUL     9.469915
# CLO     9.880812
# BEL    14.582350
# MAL    18.332051
# dtype: float64

# %%
#Step 12. Downsample the record to a yearly frequency for each location.
data.groupby(data.index.to_period('A')).mean()
# Out:
# <ipython-input-15-7f6526baf8f5>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.index.to_period('A')).mean()
#                 RPT        VAL        ROS       KIL        SHA       BIR  \
# datetime
# 1961      12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962      12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963      12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964      12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965      12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966      13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967      12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# ...

# %%
#Step 13. Downsample the record to a monthly frequency for each location.
#data.dropna().resample('M')
data.groupby(data.index.to_period('M')).mean()
# Out:
# <ipython-input-16-c413d0046d2f>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.index.to_period('M')).mean()
#                 RPT        VAL        ROS       KIL        SHA        BIR  \
# datetime
# 1961-01   13.983846  12.385833  11.666923  6.826923  10.151667   7.179231
# 1961-02   16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03   10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04   10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05    9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...             ...        ...        ...       ...        ...        ...
# 1978-08    9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# ...

# %%
#Step 14. Downsample the record to a weekly frequency for each location.
#data.dropna().resample('W')
data.groupby(data.index.to_period('W')).mean()
# Out:
# <ipython-input-17-feeea8e21424>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.index.to_period('W')).mean()
#                              RPT        VAL        ROS       KIL        SHA  \
# datetime
# 1960-12-26/1961-01-01  15.040000  14.960000  13.170000  9.290000        NaN
# 1961-01-02/1961-01-08  13.541429  11.486667  10.487143  6.417143   9.474286
# 1961-01-09/1961-01-15  12.975000  10.975000  14.750000  6.540000  10.040000
# 1961-01-16/1961-01-22   9.590000  11.830000   7.960000  1.580000   7.920000
# 1961-01-30/1961-02-05  16.827143  15.460000  12.618571  8.247143  13.361429
# ...                          ...        ...        ...       ...        ...
# 1978-11-27/1978-12-03  15.695000  12.454000  13.829000  6.538000  11.677000
# ...

# %%
#Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks
data.dropna().resample('W', origin='1961-01-02').agg(['min', 'max', 'mean', 'std'])
# Out:
# <ipython-input-18-2567a6b0d7f3>:2: FutureWarning: ['datetime'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   data.dropna().resample('W', origin='1961-01-02').agg(['min', 'max', 'mean', 'std'])
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# datetime
# 1961-01-08  10.58  13.50  12.316000  1.421418   6.63  14.29  10.408000
# 1961-01-15  12.58  13.37  12.975000  0.558614  10.83  11.12  10.975000
# 1961-01-22   9.59   9.59   9.590000       NaN  11.83  11.83  11.830000
# 1961-01-29    NaN    NaN        NaN       NaN    NaN    NaN        NaN
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# ...           ...    ...        ...       ...    ...    ...        ...
# 1978-12-03   9.08  21.54  15.695000  4.527467   4.54  21.34  12.454000
# ...

# %% [markdown]
# ##Question 5
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.
# Step 4. See the first 10 entries
# Step 5. What is the number of observations in the dataset?
# Step 6. What is the number of columns in the dataset?
# Step 7. Print the name of all the columns.
# Step 8. How is the dataset indexed?
# Step 9. Which was the most-ordered item?
# Step 10. For the most-ordered item, how many items were ordered?
# Step 11. What was the most ordered item in the choice_description column?
# Step 12. How many items were orderd in total?
# Step 13.
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type
# Step 14. How much was the revenue for the period in the dataset?
# Step 15. How many orders were made in the period?
# Step 16. What is the average revenue amount per order?
# Step 17. How many different items are sold?

# %%
#Step 1. Import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

# %%
#Step 2. Import the dataset from this address.
# 5.2 Data Loading
## Task 2 - Load/ data set  dataset
url2 = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
#Step 3. Assign it to a variable called chipo.
chipo= pd.read_table(url2)

# %%
#Step 4. See the first 10 entries
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#Step 5. What is the number of observations in the dataset?
chipo.shape[0]
# Out:
# 4622

# %%
#Step 6. What is the number of columns in the dataset?
chipo.shape[1]
# Out:
# 5

# %%
#Step 7. Print the name of all the columns.
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Step 8. How is the dataset indexed?
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Step 9. Which was the most-ordered item?

most_order = chipo.groupby("item_name")["quantity"].sum()
most_ordered= most_order.idxmax()
print(most_ordered)
# Out:
# Chicken Bowl

# %%
#Step 10. For the most-ordered item, how many items were ordered?
items_ordered=most_order.max()
print("for the most ordered item it had", items_ordered, "items ordered" )
# Out:
# for the most ordered item it had 761 items ordered

# %%
#Step 11. What was the most ordered item in the choice_description column?
most_ordered_choice = chipo.groupby("choice_description")["quantity"].sum().idxmax()
print(most_ordered_choice)
# Out:
# [Diet Coke]

# %%
#Step 12. How many items were orderd in total?
items_total=chipo.quantity.sum()
print(items_total)
# Out:
# 4972

# %%
#Step 13.
#• Turn the item price into a float
#• Check the item price type
#• Create a lambda function and change the type of item price
#• Check the item price type
chipo.dtypes
chipo['item_price'] = chipo['item_price'].replace('[\$,]', '', regex=True).astype(float)
print(chipo.dtypes)
print(chipo['item_price'].dtypes)
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# item_price1           float64
# dtype: object
# float64

# %%
# Applying lambda function to find
chipo['item_price1'] = chipo['item_price'].apply(lambda x: x * 2)
print(chipo['item_price1'].dtypes)
# Out:
# float64

# %%
#Step 14. How much was the revenue for the period in the dataset?
#revenue is the total of quantity*price
total_revenue = (chipo['quantity'] * chipo['item_price']).sum()
print(total_revenue)
# Out:
# 39237.02

# %%
#Step 15. How many orders were made in the period?
orders = chipo.order_id.value_counts().count()
print(orders)
# Out:
# 1834

# %%
#Step 16. What is the average revenue amount per order?
chipo['revenue'] = chipo['item_price'] * chipo['quantity']
avg_revenue =chipo['revenue'].mean()
print (avg_revenue)
# Out:
# 16.97837299870186

# %%
#Step 17. How many different items are sold?
chipo.item_name.value_counts().count()
# Out:
# 50

# %% [markdown]
# ##Question 6
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean
from matplotlib import colors

# %%
marriage_divorce = pd.read_csv('/us-marriages-divorces-1867-2014.csv')
df = pd.DataFrame(marriage_divorce, columns=["Year", "Marriages","Divorce","Population","Marriages_per_1000","Divorces_per_1000"])

years = df['Year'].values
marriages_per_capita = df['Marriages_per_1000'].values
divorces_per_capita = df['Divorces_per_1000'].values

# %%
x = years
y1 =marriages_per_capita
y2 = divorces_per_capita


plt.figure()

plt.plot(years, marriages_per_capita, color='blue', label='marriages_per_capita')
plt.plot(years, divorces_per_capita, color='orange', label='divorces_per_capita')

plt.xlabel('Years')
plt.ylabel('Per Capita')
plt.title('Marriages and Divorces Per Capita Over Time')

plt.legend()
plt.show()

# %% [markdown]
# ##Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean
from matplotlib import colors

# %%
marriage_divorce = pd.read_csv('/us-marriages-divorces-1867-2014.csv')
df = pd.DataFrame(marriage_divorce, columns=["Year", "Marriages","Divorces","Population","Marriages_per_1000","Divorces_per_1000"])

# %%
plt.figure(figsize=(10, 6))
selected_years = [1900, 1950, 2000]
df_selected_years = df[df['Year'].isin(selected_years)].copy()
# Grouped bar chart for Marriages and Divorces per Capita
bar_width = 2
bar_marriage = df_selected_years['Year'] - bar_width/2
bar_divorce = df_selected_years['Year'] + bar_width/2

plt.bar(bar_marriage, df_selected_years['Marriages_per_1000'], width=bar_width, color='blue', label='Marriages per 1000')
plt.bar(bar_divorce, df_selected_years['Divorces_per_1000'], width=bar_width, color='red', label='Divorces per 1000', alpha=0.7)

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('number of marriages and divorces per capita')
plt.title('Marriage and Divorce Rates per 1000 People in the U.S. in 1900, 1950 and  2000')
plt.legend()

# Display the chart
plt.show()

# %% [markdown]
# ##Question 8
#  Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name. Don't forget to label your axes!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean
from matplotlib import colors

# %%
kill_counts = pd.read_csv('/content/actor_kill_counts.csv')
df = pd.DataFrame(kill_counts, columns=["Actor", "Count"])
x = df.groupby('Actor')['Count'].mean().sort_values().tail(15)
ax =x.plot.barh()
ax.bar_label(ax.containers[0])
plt.title('the deadliest actors in Hollywood')
plt.ylabel('Actor')
plt.xlabel('Count')
plt.show()

# %% [markdown]
# ##Question 9
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

# %%
roman_empire = pd.read_csv('/content/roman-emperor-reigns.csv')
df = pd.DataFrame(roman_empire, columns=["Emperor", "Length_of_Reign", "Cause_of_Death"])

# %%
roman_empire.Cause_of_Death.value_counts()
# Out:
# Assassinated             22
# Natural causes           16
# Possibly assassinated     8
# Killed in battle          8
# Suicide                   5
# Illness                   5
# Executed                  3
# Died in captivity         1
# Name: Cause_of_Death, dtype: int64

# %%
cod = dict(roman_empire.Cause_of_Death.value_counts())
labels =cod.keys()
values= cod.values()
plt.figure()
plt.pie (values, labels=labels, autopct ='%.2f')
plt.show()

# %% [markdown]
# ##Question 10
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import mean
file_path = '/arcade-revenue-vs-cs-doctorates.csv'
mydata = pd.read_csv(file_path)
arcade = pd.DataFrame(mydata, columns=["Year", "Total Arcade Revenue (billions)", "Computer Science Doctorates Awarded (US)"])
print(arcade.head(12))
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
# creates the scatterplot
# Load your data

# Create a scatter plot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(x=arcade["Total Arcade Revenue (billions)"], y=arcade["Computer Science Doctorates Awarded (US)"], c=arcade["Year"], cmap="viridis")

# Label the axes
plt.xlabel("Total Arcade Revenue (billions)")
plt.ylabel("Computer Science Doctorates Awarded (US)")
plt.title("Relationship between Arcade Revenue and CS Doctorates (2000-2009)")


# Add a colorbar
cbar = plt.colorbar(scatter)
cbar.set_label("Year")
# Show the plot
plt.show()
